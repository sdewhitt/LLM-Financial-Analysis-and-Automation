# %% [markdown]
# <a href="https://colab.research.google.com/github/sdewhitt/LLM-Financial-Analysis-and-Automation/blob/main/Financial_Analysis_%26_Automation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install Libraries

# %%
! pip install yfinance langchain_pinecone openai python-dotenv langchain-community sentence_transformers --quiet

# %%
from langchain_pinecone import PineconeVectorStore
from openai import OpenAI
import dotenv
import json
import yfinance as yf
import concurrent.futures
from langchain_community.embeddings import HuggingFaceEmbeddings
from google.colab import userdata
from langchain.schema import Document
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
from pinecone import Pinecone
import numpy as np
import requests
import os

# %%
def get_stock_info(symbol: str) -> dict:
    """
    Retrieves and formats detailed information about a stock from Yahoo Finance.

    Args:
        symbol (str): The stock ticker symbol to look up.

    Returns:
        dict: A dictionary containing detailed stock information, including ticker, name,
              business summary, city, state, country, industry, and sector.
    """
    data = yf.Ticker(symbol)
    stock_info = data.info

    properties = {
        "Ticker": stock_info.get('symbol', 'Information not available'),
        'Name': stock_info.get('longName', 'Information not available'),
        'Business Summary': stock_info.get('longBusinessSummary'),
        'City': stock_info.get('city', 'Information not available'),
        'State': stock_info.get('state', 'Information not available'),
        'Country': stock_info.get('country', 'Information not available'),
        'Industry': stock_info.get('industry', 'Information not available'),
        'Sector': stock_info.get('sector', 'Information not available')
    }

    return properties

# %%
data = yf.Ticker("NVDA")
stock_info = data.info
print(stock_info)
# Out:
# {'address1': '2788 San Tomas Expressway', 'city': 'Santa Clara', 'state': 'CA', 'zip': '95051', 'country': 'United States', 'phone': '408 486 2000', 'website': 'https://www.nvidia.com', 'industry': 'Semiconductors', 'industryKey': 'semiconductors', 'industryDisp': 'Semiconductors', 'sector': 'Technology', 'sectorKey': 'technology', 'sectorDisp': 'Technology', 'longBusinessSummary': "NVIDIA Corporation provides graphics and compute and networking solutions in the United States, Taiwan, China, Hong Kong, and internationally. The Graphics segment offers GeForce GPUs for gaming and PCs, the GeForce NOW game streaming service and related infrastructure, and solutions for gaming platforms; Quadro/NVIDIA RTX GPUs for enterprise workstation graphics; virtual GPU or vGPU software for cloud-based visual and virtual computing; automotive platforms for infotainment systems; and Omniverse software for building and operating metaverse and 3D internet applications. The Compute & Networking segment comprises Data Center computing platforms and end-to-end networking platforms, including Quantum for InfiniBand and Spectrum for Ethernet; NVIDIA DRIVE automated-driving platform and automotive development agreements; Jetson robotics and other embedded platforms; NVIDIA AI Enterprise and other software; and DGX Cloud software and services. The company's products are used in gaming, professional visualization, data center, and automotive markets. It sells its products to original equipment manufacturers, original device manufacturers, system integrators and distributors, independent software vendors, cloud service providers, consumer internet companies, add-in board manufacturers, distributors, automotive manufacturers and tier-1 automotive suppliers, and other ecosystem participants. NVIDIA Corporation was incorporated in 1993 and is headquartered in Santa Clara, California.", 'fullTimeEmployees': 29600, 'companyOfficers': [{'maxAge': 1, 'name': 'Mr. Jen-Hsun  Huang', 'age': 60, 'title': 'Co-Founder, CEO, President & Director', 'yearBorn': 1963, 'fiscalYear': 2024, 'totalPay': 7491487, 'exercisedValue': 217327152, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Colette M. Kress', 'age': 56, 'title': 'Executive VP & CFO', 'yearBorn': 1967, 'fiscalYear': 2024, 'totalPay': 1510765, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Debora  Shoquist', 'age': 68, 'title': 'Executive Vice President of Operations', 'yearBorn': 1955, 'fiscalYear': 2024, 'totalPay': 1371266, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Timothy S. Teter J.D.', 'age': 56, 'title': 'Executive VP, General Counsel & Secretary', 'yearBorn': 1967, 'fiscalYear': 2024, 'totalPay': 1360939, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Ajay K. Puri', 'age': 68, 'title': 'Executive Vice President of Worldwide Field Operations', 'yearBorn': 1955, 'fiscalYear': 2024, 'totalPay': 2295097, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Chris A. Malachowsky', 'title': 'Co-Founder', 'fiscalYear': 2024, 'totalPay': 320000, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Donald F. Robertson Jr.', 'age': 54, 'title': 'VP & Chief Accounting Officer', 'yearBorn': 1969, 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Prof. William J. Dally Ph.D.', 'age': 62, 'title': 'Chief Scientist & Senior VP of Research', 'yearBorn': 1961, 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Mylene  Mangalindan', 'title': 'VP of Corporate Communications', 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Tommy  Lee', 'title': 'Senior Vice President of Systems Engineering & Application', 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}], 'auditRisk': 7, 'boardRisk': 10, 'compensationRisk': 5, 'shareHolderRightsRisk': 6, 'overallRisk': 8, 'governanceEpoc ...

# %%
def get_huggingface_embeddings(text, model_name="sentence-transformers/all-mpnet-base-v2"):
    """
    Generates embeddings for the given text using a specified Hugging Face model.

    Args:
        text (str): The input text to generate embeddings for.
        model_name (str): The name of the Hugging Face model to use.
                          Defaults to "sentence-transformers/all-mpnet-base-v2".

    Returns:
        np.ndarray: The generated embeddings as a NumPy array.
    """
    model = SentenceTransformer(model_name)
    return model.encode(text)


def cosine_similarity_between_sentences(sentence1, sentence2):
    """
    Calculates the cosine similarity between two sentences.

    Args:
        sentence1 (str): The first sentence for similarity comparison.
        sentence2 (str): The second sentence for similarity comparison.

    Returns:
        float: The cosine similarity score between the two sentences,
               ranging from -1 (completely opposite) to 1 (identical).

    Notes:
        Prints the similarity score to the console in a formatted string.
    """
    # Get embeddings for both sentences
    embedding1 = np.array(get_huggingface_embeddings(sentence1))
    embedding2 = np.array(get_huggingface_embeddings(sentence2))

    # Reshape embeddings for cosine_similarity function
    embedding1 = embedding1.reshape(1, -1)
    embedding2 = embedding2.reshape(1, -1)

    # Calculate cosine similarity
    similarity = cosine_similarity(embedding1, embedding2)
    similarity_score = similarity[0][0]
    print(f"Cosine similarity between the two sentences: {similarity_score:.4f}")
    return similarity_score


# Example usage
sentence1 = "I like walking to the park"
sentence2 = "I like running to the office"

similarity = cosine_similarity_between_sentences(sentence1, sentence2)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Cosine similarity between the two sentences: 0.6133

# %%
aapl_info = get_stock_info('AAPL')
print(aapl_info)
# Out:
# {'Ticker': 'AAPL', 'Name': 'Apple Inc.', 'Business Summary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts, as well as advertising services include third-party licensing arrangements and its own advertising platforms. In addition, the company offers various subscription-based services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.', 'City': 'Cupertino', 'State': 'CA', 'Country': 'United States', 'Industry': 'Consumer Electronics', 'Sector': 'Technology'}

# %%
aapl_description = aapl_info['Business Summary']

company_description = "I want to find companies that make smartphones and are headquarted in California"

similarity = cosine_similarity_between_sentences(aapl_description, company_description)
# Out:
# Cosine similarity between the two sentences: 0.3635

# %% [markdown]
# # Get all the Stocks in the Stock Market

# %% [markdown]
# First, we need to get the symbols (also known as tickers) of all the stocks in the stock market

# %%
def get_company_tickers():
    """
    Downloads and parses the Stock ticker symbols from the GitHub-hosted SEC company tickers JSON file.

    Returns:
        dict: A dictionary containing company tickers and related information.

    Notes:
        The data is sourced from the official SEC website via a GitHub repository:
        https://raw.githubusercontent.com/team-headstart/Financial-Analysis-and-Automation-with-LLMs/main/company_tickers.json
    """
    # URL to fetch the raw JSON file from GitHub
    url = "https://raw.githubusercontent.com/team-headstart/Financial-Analysis-and-Automation-with-LLMs/main/company_tickers.json"

    # Making a GET request to the URL
    response = requests.get(url)

    # Checking if the request was successful
    if response.status_code == 200:
        # Parse the JSON content directly
        company_tickers = json.loads(response.content.decode('utf-8'))

        # Optionally save the content to a local file for future use
        with open("company_tickers.json", "w", encoding="utf-8") as file:
            json.dump(company_tickers, file, indent=4)

        print("File downloaded successfully and saved as 'company_tickers.json'")
        return company_tickers
    else:
        print(f"Failed to download file. Status code: {response.status_code}")
        return None

company_tickers = get_company_tickers()
# Out:
# File downloaded successfully and saved as 'company_tickers.json'

# %%
company_tickers

# %%
len(company_tickers)
# Out:
# 9998

# %%
pinecone_api_key = userdata.get("PINECONE_API_KEY")
os.environ['PINECONE_API_KEY'] = pinecone_api_key

index_name = "stocks"
namespace = "stock-descriptions"

hf_embeddings = HuggingFaceEmbeddings()
vectorstore = PineconeVectorStore(index_name=index_name, embedding=hf_embeddings)
# Out:
# <ipython-input-10-8d5c0f356cf6>:7: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   hf_embeddings = HuggingFaceEmbeddings()
# <ipython-input-10-8d5c0f356cf6>:7: LangChainDeprecationWarning: Default values for HuggingFaceEmbeddings.model_name were deprecated in LangChain 0.2.16 and will be removed in 0.4.0. Explicitly pass a model_name to the HuggingFaceEmbeddings constructor instead.
#   hf_embeddings = HuggingFaceEmbeddings()

# %%
for idx, stock in company_tickers.items():
    stock_ticker = stock['ticker']
    stock_data = get_stock_info(stock_ticker)
    stock_description = stock_data['Business Summary']

    print(f"Processing stock {idx} / {len(company_tickers)} :", stock_ticker)

    vectorstore_from_documents = PineconeVectorStore.from_documents(
        documents=[Document(page_content=stock_description, metadata=stock_data)],
        embedding=hf_embeddings,
        index_name=index_name,
        namespace=namespace
    )
# Out:
# Processing stock 0 / 9998 : NVDA
# Processing stock 1 / 9998 : AAPL
# Processing stock 2 / 9998 : MSFT
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-0b4e6262b270> in <cell line: 1>()
#       6     print(f"Processing stock {idx} / {len(company_tickers)} :", stock_ticker)
#       7
# ----> 8     vectorstore_from_documents = PineconeVectorStore.from_documents(
#       9         documents=[Document(page_content=stock_description, metadata=stock_data)],
#      10         embedding=hf_embeddings,
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/vectorstores/base.py in from_documents(cls, documents, embedding, **kwargs)
#     850                 kwargs["ids"] = ids
#     851
# --> 852         return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#     853
#     854     @classmethod
#
# /usr/local/lib/python3.10/dist-packages/langchain_pinecone/vectorstores.py in from_texts(cls, texts, embedding, metadatas, ids, batch_size, text_key, namespace, index_name, upsert_kwargs, pool_threads, embeddings_chunk_size, async_req, id_prefix, **kwargs)
#     581         pinecone = cls(pinecone_index, embedding, text_key, namespace, **kwargs)
#     582
# --> 583         pinecone.add_texts(
#     584             texts,
#     585             metadatas=metadatas,
#
# /usr/local/lib/python3.10/dist-packages/langchain_pinecone/vectorstores.py in add_texts(self, texts, metadatas, ids, namespace, batch_size, embedding_chunk_size, async_req, id_prefix, **kwargs)
#     277             chunk_ids = ids[i : i + embedding_chunk_size]
#     278             chunk_metadatas = metadatas[i : i + embedding_chunk_size]
# --> 279             embeddings = self._embedding.embed_documents(chunk_texts)
#     280             vector_tuples = zip(chunk_ids, embeddings, chunk_metadatas)
#     281             if async_req:
#
# /usr/local/lib/python3.10/dist-packages/langchain_community/embeddings/huggingface.py in embed_documents(self, texts)
#     113             sentence_transformers.SentenceTransformer.stop_multi_process_pool(pool)
#     114         else:
# --> 115             embeddings = self.client.encode(
#     116                 texts, show_progress_bar=self.show_progress, **self.encode_kwargs
#     117             )
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/SentenceTransformer.py in encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, **kwargs)
#     619
#     620             with torch.no_grad():
# --> 621                 out_features = self.forward(features, **kwargs)
#     622                 if self.device.type == "hpu":
#     623                     out_features = copy.deepcopy(out_features)
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/SentenceTransformer.py in forward(self, input, **kwargs)
#     686             module_kwarg_keys = self.module_kwargs.get(module_name, [])
#     687             module_kwargs = {key: value for key, value in kwargs.items() if key in module_kwarg_keys}
# --> 688             input = module(input, **module_kwargs)
#     689         return input
#     690
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/models/Transformer.py in forward(self, features, **kwargs)
#     348             trans_features["token_type_ids"] = features["token_type_ids"]
#     349
# --> 350         output_states = self.auto_model(**trans_features, **kwargs, return_dict=False)
#     351         output_tokens = output_states[0]
#     352
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mpnet/modeling_mpnet.py in forward(self, input_ids, attention_mask, position_ids, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict, **kwargs)
#     542         head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     543         embedding_output = self.embeddings(input_ids=input_ids, position_ids=position_ids, inputs_embeds=inputs_embeds)
# --> 544         encoder_outputs = self.encoder(
#     545             embedding_output,
#     546             attention_mask=extended_attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mpnet/modeling_mpnet.py in forward(self, hidden_states, attention_mask, head_mask, output_attentions, output_hidden_states, return_dict, **kwargs)
#     332                 all_hidden_states = all_hidden_states + (hidden_states,)
#     333
# --> 334             layer_outputs = layer_module(
#     335                 hidden_states,
#     336                 attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mpnet/modeling_mpnet.py in forward(self, hidden_states, attention_mask, head_mask, position_bias, output_attentions, **kwargs)
#     301         outputs = self_attention_outputs[1:]  # add self attentions if we output attention weights
#     302
# --> 303         intermediate_output = self.intermediate(attention_output)
#     304         layer_output = self.output(intermediate_output, attention_output)
#     305         outputs = (layer_output,) + outputs
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mpnet/modeling_mpnet.py in forward(self, hidden_states)
#     255
#     256     def forward(self, hidden_states: torch.Tensor) -> torch.Tensor:
# --> 257         hidden_states = self.dense(hidden_states)
#     258         hidden_states = self.intermediate_act_fn(hidden_states)
#     259         return hidden_states
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     123
#     124     def forward(self, input: Tensor) -> Tensor:
# --> 125         return F.linear(input, self.weight, self.bias)
#     126
#     127     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
# Initialize tracking lists
successful_tickers = []
unsuccessful_tickers = []

# Load existing successful/unsuccessful tickers
try:
    with open('successful_tickers.txt', 'r') as f:
        successful_tickers = [line.strip() for line in f if line.strip()]
    print(f"Loaded {len(successful_tickers)} successful tickers")
except FileNotFoundError:
    print("No existing successful tickers file found")

try:
    with open('unsuccessful_tickers.txt', 'r') as f:
        unsuccessful_tickers = [line.strip() for line in f if line.strip()]
    print(f"Loaded {len(unsuccessful_tickers)} unsuccessful tickers")
except FileNotFoundError:
    print("No existing unsuccessful tickers file found")
# Out:
# No existing successful tickers file found
# No existing unsuccessful tickers file found

# %%
def process_stock(stock_ticker: str) -> str:
    # Skip if already processed
    if stock_ticker in successful_tickers:
        return f"Already processed {stock_ticker}"

    try:
        # Get and store stock data
        stock_data = get_stock_info(stock_ticker)
        stock_description = stock_data['Business Summary']

        # Store stock description in Pinecone
        vectorstore_from_texts = PineconeVectorStore.from_documents(
            documents=[Document(page_content=stock_description, metadata=stock_data)],
            embedding=hf_embeddings,
            index_name=index_name,
            namespace=namespace
        )

        # Track success
        with open('successful_tickers.txt', 'a') as f:
            f.write(f"{stock_ticker}\n")
        successful_tickers.append(stock_ticker)

        return f"Processed {stock_ticker} successfully"

    except Exception as e:
        # Track failure
        with open('unsuccessful_tickers.txt', 'a') as f:
            f.write(f"{stock_ticker}\n")
        unsuccessful_tickers.append(stock_ticker)

        return f"ERROR processing {stock_ticker}: {e}"

def parallel_process_stocks(tickers: list, max_workers: int = 10) -> None:
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_ticker = {
            executor.submit(process_stock, ticker): ticker
            for ticker in tickers
        }

        for future in concurrent.futures.as_completed(future_to_ticker):
            ticker = future_to_ticker[future]
            try:
                result = future.result()
                print(result)

                # Stop on error
                if result.startswith("ERROR"):
                    print(f"Stopping program due to error in {ticker}")
                    executor.shutdown(wait=False)
                    raise SystemExit(1)

            except Exception as exc:
                print(f'{ticker} generated an exception: {exc}')
                print("Stopping program due to exception")
                executor.shutdown(wait=False)
                raise SystemExit(1)

# Prepare your tickers
tickers_to_process = [company_tickers[num]['ticker'] for num in company_tickers.keys()]

# Process them
parallel_process_stocks(tickers_to_process, max_workers=10)
# Out:
# Processed TSM successfully
# Processed GOOGL successfully
# Processed META successfully
# Processed AMZN successfully
# Processed NVDA successfully
# Processed TSLA successfully
# Processed AAPL successfully
# Processed AVGO successfully
# Processed MSFT successfully
# Processed BRK-B successfully
# Processed SPY successfully
# Processed V successfully
# Processed XOM successfully
# Processed JPM successfully
# Processed UNH successfully
# Processed LLY successfully
# Processed NVO successfully
# Processed WMT successfully
# Processed ORCL successfully
# Processed HD successfully
# Processed MA successfully
# Processed NFLX successfully
# Processed RCIT successfully
# Processed COST successfully
# Processed CVX successfully
# Processed BAC successfully
# Processed CRM successfully
# Processed TMUS successfully
# Processed JNJ successfully
# Processed PG successfully
# Processed SAP successfully
# Processed ABBV successfully
# Processed KO successfully
# Processed ASML successfully
# Processed ACN successfully
# Processed TM successfully
# Processed WFC successfully
# Processed MRK successfully
# Processed CSCO successfully
# Processed ADBE successfully
# Processed MCD successfully
# Processed LIN successfully
# Processed BX successfully
# Processed PEP successfully
# Processed AMD successfully
# Processed MS successfully
# Processed PM successfully
# Processed BABA successfully
# Processed NVS successfully
# Processed AXP successfully
# Processed NOW successfully
# Processed QQQ successfully
# Processed GE successfully
# Processed DIS successfully
# Processed SHEL successfully
# Processed AZN successfully
# Processed ABT successfully
# Processed IBM successfully
# Processed TMO successfully
# Processed ISRG successfully
# Processed INTU successfully
# Processed GS successfully
# Processed TXN successfully
# Processed QCOM successfully
# Processed CAT successfully
# Processed HSBC successfully
# Processed VZ successfully
# Processed RY successfully
# Processed BKNG successfully
# Processed DHR successfully
# Processed PDD successfully
# Processed CMCSA successfully
# Processed FMX successfully
# Processed T successfully
# Processed NEE successfully
# Processed HDB successfully
# Processed RTX successfully
# Processed LOW successfully
# Processed SPGI successfully
# Processed UBER successfully
# Processed BLK successfully
# Processed UNP successfully
# Processed HON successfully
# Processed AMGN successfully
# Processed PGR successfully
# Processed PLTR successfully
# Processed SYK successfully
# Processed SCHW successfully
# Processed UL successfully
# Processed ETN successfully
# Processed SHOP successfully
# Processed AMAT successfully
# Processed TJX successfully
# Processed TTE successfully
# Processed PFE successfully
# Processed ARM successfully
# Processed BHP successfully
# Processed COP successfully
# Processed KKR successfully
# Processed MUFG successfully
# Processed C successfully
# Processed ADP successfully
# Processed RTNTF successfully
# Processed LMT successfully
# Processed PANW successfully
# Processed BSX successfully
# Processed SNY successfully
# Processed FI successfully
# Processed ANET successfully
# Processed EADSY successfully
# Processed VRTX successfully
# Processed SBUX successfully
# Processed CB successfully
# Processed NKE successfully
# Processed UPS successfully
# Processed BUD successfully
# Processed BMY successfully
# Processed PLD successfully
# Processed MMC successfully
# Processed SONY successfully
# Processed MU successfully
# Processed MDT successfully
# Processed GILD successfully
# Processed DE successfully
# Processed BA successfully
# Processed INTC successfully
# Processed RIO successfully
# Processed ADI successfully
# Processed IBN successfully
# Processed SO successfully
# Processed TD successfully
# Processed MO successfully
# Processed UBS successfully
# Processed AIQUY successfully
# Processed APP successfully
# Processed SHW successfully
# Processed SPOT successfully
# Processed MELI successfully
# Processed GEV successfully
# Processed AMT successfully
# Processed ENB successfully
# Processed ELV successfully
# Processed DELL successfully
# Processed TT successfully
# Processed LRCX successfully
# Processed APO successfully
# Processed SMFG successfully
# Processed ICE successfully
# Processed CI successfully
# Processed EQIX successfully
# Processed INFY successfully
# Processed WM successfully
# Processed PH successfully
# Processed CTAS successfully
# Processed HCA successfully
# Processed PBR successfully
# Processed DUK successfully
# Processed WELL successfully
# Processed PYPL successfully
# Processed MCO successfully
# Processed MDLZ successfully
# Processed ABNB successfully
# Processed APH successfully
# Processed BN successfully
# Processed RELX successfully
# Processed CRWD successfully
# Processed AON successfully
# Processed REGN successfully
# Processed CME successfully
# Processed CMG successfully
# Processed KLAC successfully
# Processed MSI successfully
# Processed PNC successfully
# Processed BTI successfully
# Processed CFRUY successfully
# Processed SNPS successfully
# Processed ZTS successfully
# Processed ITW successfully
# Processed RACE successfully
# Processed GD successfully
# Processed USB successfully
# Processed MAR successfully
# Processed CDNS successfully
# Processed SCCO successfully
# Processed BP successfully
# Processed EOG successfully
# Processed COIN successfully
# Processed IBKR successfully
# Processed MCK successfully
# Processed MRVL successfully
# Processed CL successfully
# Processed SAN successfully
# Processed TRI successfully
# Processed FDX successfully
# Processed EMR successfully
# Processed SHECY successfully
# Processed DASH successfully
# Processed CNQ successfully
# Processed MMM successfully
# Processed MSTR successfully
# Processed NOC successfully
# Processed FTNT successfully
# Processed APD successfully
# Processed TGT successfully
# Processed CEG successfully
# Processed CP successfully
# Processed COF successfully
# Processed CNI successfully
# Processed ORLY successfully
# Processed GSK successfully
# Processed TDG successfully
# Processed ECL successfully
# Processed WMB successfully
# Processed BMO successfully
# Processed WDAY successfully
# Processed CSX successfully
# Processed SPG successfully
# Processed BNS successfully
# Processed EPD successfully
# Processed NU successfully
# Processed CVS successfully
# Processed RSG successfully
# Processed CRH successfully
# Processed EQNR successfully
# Processed DEO successfully
# Processed AJG successfully
# Processed CARR successfully
# Processed BDX successfully
# Processed RCL successfully
# Processed GM successfully
# Processed TOELY successfully
# Processed GLD successfully
# Processed ANZGY successfully
# Processed AFL successfully
# Processed OKE successfully
# Processed ADSK successfully
# Processed TEAM successfully
# Processed DLR successfully
# Processed TFC successfully
# Processed FCX successfully
# Processed NGG successfully
# Processed MBGYY successfully
# Processed CM successfully
# Processed HLT successfully
# Processed MFG successfully
# Processed SLB successfully
# Processed KMI successfully
# Processed NSC successfully
# Processed PSA successfully
# Processed TTD successfully
# Processed TRV successfully
# Processed ROP successfully
# Processed ET successfully
# Processed GLNCY successfully
# Processed PCAR successfully
# Processed SE successfully
# Processed JD successfully
# Processed GWW successfully
# Processed BBVA successfully
# Processed SRE successfully
# Processed MFC successfully
# Processed JCI successfully
# Processed MET successfully
# Processed NXPI successfully
# Processed BK successfully
# Processed ITUB successfully
# Processed CHTR successfully
# Processed PCG successfully
# Processed FICO successfully
# Processed URI successfully
# Processed AMP successfully
# Processed PSX successfully
# Processed CPRT successfully
# Processed DHI successfully
# Processed NTES successfully
# Processed PTCAY successfully
# Processed ARES successfully
# Processed FANG successfully
# Processed AZO successfully
# Processed AEP successfully
# Processed SU successfully
# Processed PAYX successfully
# Processed CTA-PA successfully
# Processed ALL successfully
# Processed TRP successfully
# Processed MNST successfully
# Processed SQ successfully
# Processed MPC successfully
# Processed GBTC successfully
# Processed BAESY successfully
# Processed BCS successfully
# Processed O successfully
# Processed ING successfully
# Processed D successfully
# Processed VST successfully
# Processed CMI successfully
# Processed FIS successfully
# Processed MPLX successfully
# Processed LNG successfully
# Processed WCN successfully
# Processed IAU successfully
# Processed PWR successfully
# Processed CODYY successfully
# Processed AIG successfully
# Processed FAST successfully
# Processed OXY successfully
# Processed FLUT successfully
# Processed ROST successfully
# Processed NEM successfully
# Processed COR successfully
# Processed AMX successfully
# Processed LHX successfully
# Processed ODFL successfully
# Processed E successfully
# Processed MSCI successfully
# Processed KVUE successfully
# Processed LEN successfully
# Processed HWM successfully
# Processed CCI successfully
# Processed AXON successfully
# Processed PRU successfully
# Processed HES successfully
# Processed KMB successfully
# Processed VRT successfully
# Processed NDAQ successfully
# Processed F successfully
# Processed DFS successfully
# Processed TEL successfully
# Processed VLO successfully
# Processed AME successfully
# Processed CPNG successfully
# Processed BMWKY successfully
# Processed PEG successfully
# Processed STZ successfully
# Processed DDOG successfully
# Processed LYG successfully
# Processed KDP successfully
# Processed CAIXY successfully
# Processed CRARY successfully
# Processed TAK successfully
# Processed EA successfully
# Processed DNZOY successfully
# Processed VALE successfully
# Processed HLN successfully
# Processed TRGP successfully
# Processed SNOW successfully
# Processed ALC successfully
# Processed KR successfully
# Processed ATEYY successfully
# Processed NWG successfully
# Processed SVNDY successfully
# Processed DAL successfully
# Processed IT successfully
# Processed BKR successfully
# Processed HMC successfully
# Processed FERG successfully
# Processed XEL successfully
# Processed IR successfully
# Processed GRMN successfully
# Processed CBRE successfully
# Processed LULU successfully
# Processed GLW successfully
# Processed VRSK successfully
# Processed OTIS successfully
# Processed EW successfully
# Processed EXC successfully
# Processed AEM successfully
# Processed OLCLY successfully
# Processed TCOM successfully
# Processed IMO successfully
# Processed STLA successfully
# Processed CTVA successfully
# Processed CTSH successfully
# Processed YUM successfully
# Processed ACGL successfully
# Processed KHC successfully
# Processed VMC successfully
# Processed WTKWY successfully
# Processed EXR successfully
# Processed SYY successfully
# Processed PPERY successfully
# Processed DIA successfully
# Processed GEHC successfully
# Processed MLM successfully
# Processed A successfully
# Processed HPQ successfully
# Processed MTB successfully
# Processed WIT successfully
# Processed LVS successfully
# Processed CCEP successfully
# Processed IQV successfully
# Processed HSY successfully
# Processed HUBS successfully
# Processed DKILY successfully
# Processed GIS successfully
# Processed SLF successfully
# Processed VEEV successfully
# Processed ABEV successfully
# Processed RBLX successfully
# Processed IDXX successfully
# Processed NUE successfully
# Processed IRM successfully
# Processed ARGX successfully
# Processed RMD successfully
# Processed HIG successfully
# Processed DD successfully
# Processed MCHP successfully
# Processed OWL successfully
# Processed WAB successfully
# Processed BSBR successfully
# Processed ED successfully
# Processed AVB successfully
# Processed VICI successfully
# Processed MDY successfully
# Processed HUM successfully
# Processed CCL successfully
# Processed DB successfully
# Processed EIX successfully
# Processed RJF successfully
# Processed ROK successfully
# Processed ETR successfully
# Processed HEI successfully
# Processed ANYYY successfully
# Processed GWLIF successfully
# Processed MRAAY successfully
# Processed BRO successfully
# Processed FITB successfully
# Processed FRFHF successfully
# Processed WTW successfully
# Processed TTWO successfully
# Processed TPL successfully
# Processed FCNCA successfully
# Processed ALNY successfully
# Processed EFX successfully
# Processed WEC successfully
# Processed QSR successfully
# Processed DOW successfully
# Processed UAL successfully
# Processed DXCM successfully
# Processed ZS successfully
# Processed CHT successfully
# Processed NET successfully
# Processed BIDU successfully
# Processed EBAY successfully
# Processed GPN successfully
# Processed GOLD successfully
# Processed LYV successfully
# Processed TSCO successfully
# Processed XYL successfully
# Processed WDS successfully
# Processed DSCSY successfully
# Processed EQR successfully
# Processed CSGP successfully
# Processed CNC successfully
# Processed PPRUY successfully
# Processed ANSS successfully
# Processed CVNA successfully
# Processed CAH successfully
# Processed CVE successfully
# Processed CUK successfully
# Processed TW successfully
# Processed FER successfully
# Processed PPG successfully
# Processed HOOD successfully
# Processed NVR successfully
# Processed STT successfully
# Processed OEZVY successfully
# Processed K successfully
# Processed ON successfully
# Processed WPM successfully
# Processed IOT successfully
# Processed DOV successfully
# Processed MPWR successfully
# Processed RKT successfully
# Processed VTR successfully
# Processed HPE successfully
# Processed LYB successfully
# Processed ERIC successfully
# Processed NVZMY successfully
# Processed DECK successfully
# Processed SW successfully
# Processed PHM successfully
# Processed BR successfully
# Processed AWK successfully
# Processed TROW successfully
# Processed CHD successfully
# Processed HAL successfully
# Processed FUJIY successfully
# Processed PUBGY successfully
# Processed FTV successfully
# Processed CQP successfully
# Processed EQT successfully
# Processed KEYS successfully
# Processed ADM successfully
# Processed GDDY successfully
# Processed NTDTY successfully
# Processed CPAY successfully
# Processed DVN successfully
# Processed TYL successfully
# Processed HBAN successfully
# Processed VLTO successfully
# Processed SYF successfully
# Processed PPL successfully
# Processed TEF successfully
# Processed DTE successfully
# Processed FANUY successfully
# Processed BCE successfully
# Processed MTD successfully
# Processed RYAAY successfully
# Processed IX successfully
# Processed ZM successfully
# Processed AEE successfully
# Processed ROL successfully
# Processed PHG successfully
# Processed KB successfully
# Processed BEKE successfully
# Processed GIB successfully
# Processed NOK successfully
# Processed BBD successfully
# Processed PBA successfully
# Processed FE successfully
# Processed LI successfully
# Processed SBAC successfully
# Processed RF successfully
# Processed NTAP successfully
# Processed BAM successfully
# Processed TPG successfully
# Processed CINF successfully
# Processed HUBB successfully
# Processed CDW successfully
# Processed CCJ successfully
# Processed BNTX successfully
# Processed LPLA successfully
# Processed DIDIY successfully
# Processed BIIB successfully
# Processed TECK successfully
# Processed TOST successfully
# Processed EXPE successfully
# Processed TSN successfully
# Processed EME successfully
# Processed VOD successfully
# Processed NTR successfully
# Processed GFS successfully
# Processed WST successfully
# Processed WRB successfully
# Processed HDELY successfully
# Processed EL successfully
# Processed ES successfully
# Processed TU successfully
# Processed ATO successfully
# Processed WY successfully
# Processed FNV successfully
# Processed PTC successfully
# Processed WBD successfully
# Processed STM successfully
# Processed EXE successfully
# Processed RDDT successfully
# Processed ZBH successfully
# Processed IFF successfully
# Processed MKL successfully
# Processed FTS successfully
# Processed TDY successfully
# Processed PUK successfully
# Processed KSPI successfully
# Processed ILMN successfully
# Processed STE successfully
# Processed LII successfully
# Processed WDC successfully
# Processed LDOS successfully
# Processed SMPNY successfully
# Processed WAT successfully
# Processed ERIE successfully
# Processed NTRS successfully
# Processed PKG successfully
# Processed EJPRY successfully
# Processed WSO successfully
# Processed ASX successfully
# Processed CBOE successfully
# Processed NJDCY successfully
# Processed STLD successfully
# Processed INVH successfully
# Processed BGNE successfully
# Processed CLX successfully
# Processed FSLR successfully
# Processed SNWV successfully
# Processed CFG successfully
# Processed STX successfully
# Processed MDB successfully
# Processed TS successfully
# Processed CMS successfully
# Processed UI successfully
# Processed ESS successfully
# Processed BLDR successfully
# Processed CJPRY successfully
# Processed FOXA successfully
# Processed CSL successfully
# Processed DRI successfully
# Processed CNP successfully
# Processed IP successfully
# Processed MKC successfully
# Processed COO successfully
# Processed BBY successfully
# Processed ZBRA successfully
# Processed MT successfully
# Processed PFG successfully
# Processed LH successfully
# Processed VIK successfully
# Processed LUV successfully
# Processed YAHOY successfully
# Processed BAH successfully
# Processed DKNG successfully
# Processed CHKP successfully
# Processed SHG successfully
# Processed PINS successfully
# Processed RCI successfully
# Processed IHG successfully
# Processed BF-A successfully
# Processed GRAB successfully
# Processed NTRA successfully
# Processed MAA successfully
# Processed KEY successfully
# Processed CTRA successfully
# Processed RYAN successfully
# Processed OMC successfully
# Processed TRU successfully
# Processed NRG successfully
# Processed SGSOY successfully
# Processed SNA successfully
# Processed TEVA successfully
# Processed NTNX successfully
# Processed FDS successfully
# Processed PODD successfully
# Processed BALL successfully
# Processed ARE successfully
# Processed JBHT successfully
# Processed YUMC successfully
# Processed HOLX successfully
# Processed TME successfully
# Processed SSNC successfully
# Processed GEN successfully
# Processed AER successfully
# Processed L successfully
# Processed SNAP successfully
# Processed DGX successfully
# Processed VRSN successfully
# Processed CG successfully
# Processed SYM successfully
# Processed AFRM successfully
# Processed ULTA successfully
# Processed J successfully
# Processed PNR successfully
# Processed GFL successfully
# Processed NMR successfully
# Processed IEX successfully
# Processed CRBG successfully
# Processed UMC successfully
# Processed RPM successfully
# Processed BURL successfully
# Processed ZTO successfully
# Processed RBA successfully
# Processed KOF successfully
# Processed EXPD successfully
# Processed NI successfully
# Processed TRMB successfully
# Processed GPC successfully
# Processed WMG successfully
# Processed XPO successfully
# Processed MOH successfully
# Processed ONON successfully
# Processed ALGN successfully
# Processed RS successfully
# Processed ZG successfully
# Processed KIM successfully
# Processed NWSA successfully
# Processed MAS successfully
# Processed SUI successfully
# Processed MANH successfully
# Processed BEP successfully
# Processed TER successfully
# Processed UDR successfully
# Processed FNF successfully
# Processed DG successfully
# Processed CAVA successfully
# Processed OC successfully
# Processed WSM successfully
# Processed DKS successfully
# Processed EC successfully
# Processed FTAI successfully
# Processed BAX successfully
# Processed LINE successfully
# Processed WLK successfully
# Processed MRO successfully
# Processed UTHR successfully
# Processed HRL successfully
# Processed DOCU successfully
# Processed GWRE successfully
# Processed AMH successfully
# Processed JHX successfully
# Processed TLK successfully
# Processed FIX successfully
# Processed PKX successfully
# Processed EG successfully
# Processed AVY successfully
# Processed TXT successfully
# Processed AZPN successfully
# Processed BIP successfully
# Processed DT successfully
# Processed RGA successfully
# Processed TOL successfully
# Processed ICLR successfully
# Processed EDPFY successfully
# Processed PSTG successfully
# Processed LNT successfully
# Processed JEF successfully
# Processed RPRX successfully
# Processed USFD successfully
# Processed CF successfully
# Processed DPZ successfully
# Processed BAP successfully
# Processed AMCR successfully
# Processed VIV successfully
# Processed TWLO successfully
# Processed VTRS successfully
# Processed GGG successfully
# Processed EQH successfully
# Processed ENTG successfully
# Processed DOC successfully
# Processed CASY successfully
# Processed EVRG successfully
# Processed SOFI successfully
# Processed H successfully
# Processed KKPNY successfully
# Processed BZLFY successfully
# Processed WES successfully
# Processed THC successfully
# Processed NDSN successfully
# Processed INCY successfully
# Processed ACM successfully
# Processed ELS successfully
# Processed MORN successfully
# Processed FLEX successfully
# Processed EWBC successfully
# Processed JBL successfully
# Processed SFM successfully
# Processed EBR successfully
# Processed WLMIY successfully
# Processed JBSAY successfully
# Processed SN successfully
# Processed MRNA successfully
# Processed COHR successfully
# Processed BSY successfully
# Processed AVTR successfully
# Processed DLTR successfully
# Processed YPF successfully
# Processed BXP successfully
# Processed SAIA successfully
# Processed FFIV successfully
# Processed AGR successfully
# Processed SMMT successfully
# Processed DUOL successfully
# Processed ARCC successfully
# Processed ALAB successfully
# Processed POOL successfully
# Processed EPAM successfully
# Processed REG successfully
# Processed GLPI successfully
# Processed CNH successfully
# Processed GMAB successfully
# Processed SWKS successfully
# Processed CW successfully
# Processed RNR successfully
# Processed OMVKY successfully
# Processed UNM successfully
# Processed UHS successfully
# Processed CLH successfully
# Processed TXRH successfully
# Processed RVTY successfully
# Processed CNA successfully
# Processed SUZ successfully
# Processed TPR successfully
# Processed AKAM successfully
# Processed SWK successfully
# Processed DVA successfully
# Processed LAMR successfully
# Processed CYBR successfully
# Processed CHRW successfully
# Processed PFGC successfully
# Processed CHWY successfully
# Processed MNDY successfully
# Processed FMS successfully
# Processed TAP successfully
# Processed CPT successfully
# Processed RTO successfully
# Processed JBAXY successfully
# Processed RL successfully
# Processed NNGRY successfully
# Processed CAG successfully
# Processed BG successfully
# Processed CPB successfully
# Processed HLI successfully
# Processed PAYC successfully
# Processed MGA successfully
# Processed LBRDA successfully
# Processed APTV successfully
# Processed XPEV successfully
# Processed RKUNY successfully
# Processed JKHY successfully
# Processed JLL successfully
# Processed GFI successfully
# Processed OKTA successfully
# Processed HST successfully
# Processed WPC successfully
# Processed ITT successfully
# Processed MBLY successfully
# Processed FUTU successfully
# Processed PPC successfully
# Processed TFII successfully
# Processed ALLE successfully
# Processed PAA successfully
# Processed SSMXY successfully
# Processed JNPR successfully
# Processed GME successfully
# Processed PTBRY successfully
# Processed KMX successfully
# Processed SCI successfully
# Processed JPXGY successfully
# Processed BMRN successfully
# Processed PR successfully
# Processed RDY successfully
# Processed ALB successfully
# Processed NVT successfully
# Processed DAY successfully
# Processed INSM successfully
# Processed LOGI successfully
# Processed FTI successfully
# Processed NBIX successfully
# Processed BJ successfully
# Processed SF successfully
# Processed EMN successfully
# Processed SOLV successfully
# Processed SGIOY successfully
# Processed NCLH successfully
# Processed SBS successfully
# Processed AFG successfully
# Processed LECO successfully
# Processed TKHVY successfully
# Processed UHAL successfully
# Processed BCH successfully
# Processed POAHY successfully
# Processed AA successfully
# Processed BWXT successfully
# Processed KGC successfully
# Processed NDEKY successfully
# Processed SJM successfully
# Processed BEN successfully
# Processed OVV successfully
# Processed EVR successfully
# Processed ATR successfully
# Processed OHI successfully
# Processed MGM successfully
# Processed HTHT successfully
# Processed AIZ successfully
# Processed WPP successfully
# Processed RRX successfully
# Processed NLY successfully
# Processed PCTY successfully
# Processed ACI successfully
# Processed GMED successfully
# Processed CUBE successfully
# Processed ALLY successfully
# Processed FND successfully
# Processed LW successfully
# Processed TTEK successfully
# Processed MMYT successfully
# Processed KIKOY successfully
# Processed KNSL successfully
# Processed ALSMY successfully
# Processed VDMCY successfully
# Processed NICE successfully
# Processed PCVX successfully
# Processed MUSA successfully
# Processed TECH successfully
# Processed SNN successfully
# Processed CCK successfully
# Processed PAG successfully
# Processed CTLT successfully
# Processed FHN successfully
# Processed CART successfully
# Processed GNRC successfully
# Processed AAON successfully
# Processed AEG successfully
# Processed SMKUY successfully
# Processed MTZ successfully
# Processed WTRG successfully
# Processed HLNE successfully
# Processed EMRAF successfully
# Processed BPYPP successfully
# Processed SQM successfully
# Processed ESLT successfully
# Processed HNGKY successfully
# Processed PNW successfully
# Processed AOS successfully
# Processed COKE successfully
# Processed CACI successfully
# Processed KEP successfully
# Processed TLN successfully
# Processed SEIC successfully
# Processed SMCI successfully
# Processed CHDN successfully
# Processed PSN successfully
# Processed BLD successfully
# Processed PCOR successfully
# Processed CRRFY successfully
# Processed AIT successfully
# Processed WWD successfully
# Processed WBS successfully
# Processed IPG successfully
# Processed ROKU successfully
# Processed EHC successfully
# Processed WMS successfully
# Processed UWMC successfully
# Processed AYI successfully
# Processed RIVN successfully
# Processed EXP successfully
# Processed AU successfully
# Processed MLI successfully
# Processed ALSN successfully
# Processed PSO successfully
# Processed LAD successfully
# Processed CSXXY successfully
# Processed LKQ successfully
# Processed ULS successfully
# Processed ARMK successfully
# Processed WCC successfully
# Processed CR successfully
# Processed PRI successfully
# Processed EXEL successfully
# Processed WAL successfully
# Processed KAIKY successfully
# Processed WYNN successfully
# Processed WIX successfully
# Processed MKTX successfully
# Processed MEDP successfully
# Processed AES successfully
# Processed SRPT successfully
# Processed AS successfully
# Processed RBC successfully
# Processed DTM successfully
# Processed REXR successfully
# Processed FRT successfully
# Processed APG successfully
# Processed CIEN successfully
# Processed VNOM successfully
# Processed CRL successfully
# Processed SNX successfully
# Processed TKO successfully
# Processed DOX successfully
# Processed GTLB successfully
# Processed KVYO successfully
# Processed DSGX successfully
# Processed CLS successfully
# Processed SLV successfully
# Processed AR successfully
# Processed PNFP successfully
# Processed TPX successfully
# Processed NIO successfully
# Processed ORI successfully
# Processed STN successfully
# Processed UUGRY successfully
# Processed RDEIY successfully
# Processed BRBR successfully
# Processed AAL successfully
# Processed WING successfully
# Processed RKLB successfully
# Processed SARO successfully
# Processed DSEEY successfully
# Processed RVMD successfully
# Processed RGLD successfully
# Processed DOCS successfully
# Processed EXAS successfully
# Processed FBIN successfully
# Processed SKX successfully
# Processed CBSH successfully
# Processed DCI successfully
# Processed GL successfully
# Processed INGR successfully
# Processed EDU successfully
# Processed PEN successfully
# Processed CMA successfully
# Processed QGEN successfully
# Processed VFS successfully
# Processed BIO successfully
# Processed BSAC successfully
# Processed KNX successfully
# Processed FLR successfully
# Processed IDKOY successfully
# Processed EDR successfully
# Processed ITCI successfully
# Processed DRS successfully
# Processed XP successfully
# Processed MTSI successfully
# Processed CFR successfully
# Processed PAC successfully
# Processed MHK successfully
# Processed CFLT successfully
# Processed ESTC successfully
# Processed BRX successfully
# Processed BILL successfully
# Processed ALTR successfully
# Processed IHICY successfully
# Processed TFX successfully
# Processed YMM successfully
# Processed CRS successfully
# Processed ZION successfully
# Processed AXTA successfully
# Processed FYBR successfully
# Processed SIRI successfully
# Processed HQY successfully
# Processed WTFC successfully
# Processed CNM successfully
# Processed HAS successfully
# Processed GLOB successfully
# Processed NYT successfully
# Processed FOUR successfully
# Processed OGE successfully
# Processed LUMN successfully
# Processed AUR successfully
# Processed MASI successfully
# Processed VNO successfully
# Processed BILI successfully
# Processed EGP successfully
# Processed SUM successfully
# Processed SKM successfully
# Processed MOS successfully
# Processed AGNC successfully
# Processed HSIC successfully
# Processed FSV successfully
# Processed BIRK successfully
# Processed GPK successfully
# Processed CHE successfully
# Processed JCYGY successfully
# Processed USO successfully
# Processed FN successfully
# Processed LNW successfully
# Processed WF successfully
# Processed LTM successfully
# Processed APPF successfully
# Processed APA successfully
# Processed TTC successfully
# Processed ADC successfully
# Processed S successfully
# ERROR processing PHYS: 1 validation error for Document
# page_content
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# Stopping program due to error in PHYS
# ---------------------------------------------------------------------------
# SystemExit                                Traceback (most recent call last)
# <ipython-input-12-fdec19a42429> in parallel_process_stocks(tickers, max_workers)
#      50                     executor.shutdown(wait=False)
# ---> 51                     raise SystemExit(1)
#      52
#
# SystemExit: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-fdec19a42429> in <cell line: 63>()
#      61
#      62 # Process them
# ---> 63 parallel_process_stocks(tickers_to_process, max_workers=10)
#
# <ipython-input-12-fdec19a42429> in parallel_process_stocks(tickers, max_workers)
#      33
#      34 def parallel_process_stocks(tickers: list, max_workers: int = 10) -> None:
# ---> 35     with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
#      36         future_to_ticker = {
#      37             executor.submit(process_stock, ticker): ticker
#
# /usr/lib/python3.10/concurrent/futures/_base.py in __exit__(self, exc_type, exc_val, exc_tb)
#     647
#     648     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 649         self.shutdown(wait=True)
#     650         return False
#     651
#
# /usr/lib/python3.10/concurrent/futures/thread.py in shutdown(self, wait, cancel_futures)
#     233         if wait:
#     234             for t in self._threads:
# --> 235                 t.join()
#     236     shutdown.__doc__ = _base.Executor.shutdown.__doc__
#
# /usr/lib/python3.10/threading.py in join(self, timeout)
#    1094
#    1095         if timeout is None:
# -> 1096             self._wait_for_tstate_lock()
#    1097         else:
#    1098             # the behavior of a negative timeout isn't documented, but
#
# /usr/lib/python3.10/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1114
#    1115         try:
# -> 1116             if lock.acquire(block, timeout):
#    1117                 lock.release()
#    1118                 self._stop()
#
# KeyboardInterrupt:

# %% [markdown]
# # Perform RAG

# %%
# Initialize Pinecone
pc = Pinecone(api_key=userdata.get("PINECONE_API_KEY"),)

# Connect to your Pinecone index
pinecone_index = pc.Index(index_name)

# %%
query = "What are some companies that manufacture consumer hardware?"
raw_query_embedding = get_huggingface_embeddings(query)
top_matches = pinecone_index.query(vector=raw_query_embedding.tolist(), top_k=10, include_metadata=True, namespace=namespace)
top_matches
# Out:
# {'matches': [{'id': '4285afa9-7bc3-4587-941f-e8e702a35b8e',
#               'metadata': {'Business Summary': 'Kimball Electronics, Inc. '
#                                                'engages in the provision of '
#                                                'electronics manufacturing, '
#                                                'engineering, and supply chain '
#                                                'support services to customers '
#                                                'in the automotive, medical, '
#                                                'and industrial end markets. '
#                                                'The Company also offers '
#                                                'contract manufacturing '
#                                                'services, including '
#                                                'engineering and supply chain '
#                                                'support for the production of '
#                                                'electronic assemblies and '
#                                                'other products, including '
#                                                'non-electronic components, '
#                                                'medical devices, medical '
#                                                'disposables, and precision '
#                                                'molded plastics, as well as '
#                                                'automation, test, and '
#                                                'inspection equipment primarily '
#                                                'used in automotive, medical, '
#                                                'and industrial applications. '
#                                                'In addition, it is also '
#                                                'involved in the production and '
#                                                'testing of printed circuit '
#                                                'board assemblies, as well as '
#                                                'clean room assembly, cold '
#                                                'chain, and product '
#                                                'sterilization management '
#                                                'activities. Further, the '
#                                                'company offers design services '
#                                                'and support, supply chain '
#                                                'services and support, rapid '
#                                                'prototyping and new product '
#                                                'introduction support, product '
#                                                'design and process validation '
#                                                'and qualification, '
#                                                'industrialization and '
#                                                'automation of manufacturing '
#                                                'processes, reliability '
#                                                'testing, aftermarket services, '
#                                                'drug delivery devices and '
#                                                'solutions with and without '
#                                                'electronics, and product life '
#                                                'cycle management services, as '
#                                                'well as and assembly of '
#                                                'medical, automotive, and '
#                                                'industrial products. It '
#                                                'operates in the United States, '
#                                                'China, Mexico, Poland, '
#                                                'Romania, Thailand, India, '
#                                                'Japan, Vietnam, and '
#                                                'internationally. Kimball '
#                                                'Electronics, Inc. was founded '
#                                                'in 1961 and is headquartered '
#                                                'in Jasper, Indiana.',
#                            'City': 'Jasper',
#                            'Country': 'United States',
#                            'Industry': 'Electrical Equipment & Parts',
#                            'Name': 'Kimball Electronics, Inc.',
#                            'Sector': 'Industrials',
#                            'State': 'IN',
#                            'Ticker': 'KE',
#                            'text': 'Kimball Electronics, Inc. engages in the '
#                                    'provision of electronics manufacturing, '
#                                    'engineering, and supply chain support '
#                                    'services to customers in the automotive, '
#                                    'medical, and industrial end markets. The '
#                                    'Company also offers contract manufacturing '
#                                    'services, including engineering and supply '
#                                    'chain support for the production of '
#                                    'electronic assemblies and other products, '
#                                    'including non-electronic components, '
#                                    'medical devices, medical disposables, and '
#                                    'precision molded plastics, as well as '
#                                    'automation, test, and inspection equipment '
#                                    'primarily used in automotive, medical, and '
#                                    'industrial applications. In addition, it '
#                                    'is also involved in the production and '
#                                    'testing of printed circuit board '
#                                    'assemblies, as well as clean room '
#                                    'assembly, cold chain, and product '
#                                    'sterilization management activities. '
#                                    'Further, the company offers design '
#                                    'services and support, supply chain '
#                                    'services and support, rapid prototyping '
#                                    'and new product introduction support, '
#                                    'product design and process validation and '
#                                    'qualification, industrialization and '
#                                    'automation of manufacturing processes, '
#                                    'reliability testing, aftermarket services, '
#                                    'drug delivery devices and solutions with '
#                                    'and without electronics, and product life '
#                                    'cycle management services, as well as and '
#                                    'assembly of medical, automotive, and '
#                                    'industrial products. It operates in the '
#                                    'United States, China, Mexico, Poland, '
#                                    'Romania, Thailand, India, Japan, Vietnam, '
#                                    'and internationally. Kimball Electronics, '
#                                    'Inc. was founded in 1961 and is '
#                                    'headquartered in Jasper, Indiana.'},
#               'score': 0.527557552,
#               'values': []},
#              {'id': '72cef324-76c7-4680-b460-2f9d37fea7da',
#               'metadata': {'Business Summary': 'Standex International '
#                                                'Corporation, together with '
#                                                'subsidiaries, engages in the '
#                                                'manufacture and sale of '
#                                                'various products and services '
#                                                'for commercial and industrial '
#                                                'markets in the United States '
#                                                'and internationally. It '
#                                                'operates through five '
#                                                'segments: Electronics, '
#                                                'Engraving, Scientific, '
#                                                'Engineering Technologies, and '
#                                                'Specialty Solutions. The '
#                                                'Electronics segment offers '
#                                                'reed relays, fluid level, '
#                                                'proximity, motion, flow, HVAC '
#                                                'condensate, and custom '
#                                                'electronics sensors; and '
#                                                'custom wound transformers and '
#                                                'inductors for low and high '
#                                                'frequency, current sense '
#                                                'technology, advanced planar '
#                                                'transformer technology, value '
#                                                'added assembly, and mechanical '
#                                                'packaging applications under '
#                                                'the Standex Electronics, '
#                                                'Renco, and Agile Magnetics. '
#                                                'The Engraving segment provides '
#                                                'mold texturizing, slush '
#                                                'molding tools, roll engraving, '
#                                                'hygiene product tooling, and '
#                                                'low observation vents, as well '
#                                                'as project management and '
#                                                'design services for stealth '
#                                                'aircraft; and process '
#                                                'machinery for various '
#                                                'industries under the Piazza '
#                                                'Rosa, World Client Services, '
#                                                'Tenibac-Graphion, GS '
#                                                'Engineering, and Innovent '
#                                                'brand names. The Scientific '
#                                                'segment offers '
#                                                'temperature-controlled '
#                                                'equipment for the medical, '
#                                                'scientific, pharmaceutical, '
#                                                'biotech, and industrial '
#                                                'markets under the American '
#                                                'BioTech Supply, Lab Research '
#                                                'Products, Corepoint, Cryosafe, '
#                                                'CryoGuard, and Scientific '
#                                                'brands. The Engineering '
#                                                'Technologies segment offers '
#                                                'net and near net formed '
#                                                'single-source customized '
#                                                'solutions that are used in the '
#                                                'manufacture of engineered '
#                                                'components for the aviation, '
#                                                'aerospace, defense, energy, '
#                                                'industrial, medical, marine, '
#                                                'oil and gas, and manned and '
#                                                'unmanned space markets under '
#                                                'the Spincraft brand. The '
#                                                'Specialty Solutions segment '
#                                                'manufactures and sells '
#                                                'refrigerated, heated, and dry '
#                                                'merchandizing display cases; '
#                                                'and single and double acting '
#                                                'telescopic, and piston rod '
#                                                'hydraulic cylinders under the '
#                                                'Federal and Custom Hoist '
#                                                'brands. The company was '
#                                                'founded in 1955 and is '
#                                                'headquartered in Salem, New '
#                                                'Hampshire.',
#                            'City': 'Salem',
#                            'Country': 'United States',
#                            'Industry': 'Specialty Industrial Machinery',
#                            'Name': 'Standex International Corporation',
#                            'Sector': 'Industrials',
#                            'State': 'NH',
#                            'Ticker': 'SXI',
#                            'text': 'Standex International Corporation, '
#                                    'together with subsidiaries, engages in the '
#                                    'manufacture and sale of various products '
#                                    'and services for commercial and industrial '
#                                    'markets in the United States and '
#                                    'internationally. It operates through five '
#                                    'segments: Electronics, Engraving, '
#                                    'Scientific, Engineering Technologies, and '
#                                    'Specialty Solutions. The Electronics '
#                                    'segment offers reed relays, fluid level, '
#                                    'proximity, motion, flow, HVAC condensate, '
#                                    'and custom electronics sensors; and custom '
#                                    'wound transformers and inductors for low '
#                                    'and high frequency, current sense '
#                                    'technology, advanced planar transformer '
#                                    'technology, value added assembly, and '
#                                    'mechanical packaging applications under '
#                                    'the Standex Electronics, Renco, and Agile '
#                                    'Magnetics. The Engraving segment provides '
#                                    'mold texturizing, slush molding tools, '
#                                    'roll engraving, hygiene product tooling, '
#                                    'and low observation vents, as well as '
#                                    'project management and design services for '
#                                    'stealth aircraft; and process machinery '
#                                    'for various industries under the Piazza '
#                                    'Rosa, World Client Services, '
#                                    'Tenibac-Graphion, GS Engineering, and '
#                                    'Innovent brand names. The Scientific '
#                                    'segment offers temperature-controlled '
#                                    'equipment for the medical, scientific, '
#                                    'pharmaceutical, biotech, and industrial '
#                                    'markets under the American BioTech Supply, '
#                                    'Lab Research Products, Corepoint, '
#                                    'Cryosafe, CryoGuard, and Scientific '
#                                    'brands. The Engineering Technologies '
#                                    'segment offers net and near net formed '
#                                    'single-source customized solutions that '
#                                    'are used in the manufacture of engineered '
#                                    'components for the aviation, aerospace, '
#                                    'defense, energy, industrial, medical, '
#                                    'marine, oil and gas, and manned and '
#                                    'unmanned space markets under the Spincraft '
#                                    'brand. The Specialty Solutions segment '
#                                    'manufactures and sells refrigerated, '
#                                    'heated, and dry merchandizing display '
#                                    'cases; and single and double acting '
#                                    'telescopic, and piston rod hydraulic '
#                                    'cylinders under the Federal and Custom '
#                                    'Hoist brands. The company was founded in '
#                                    '1955 and is headquartered in Salem, New '
#                                    'Hampshire.'},
#               'score': 0.509246945,
#               'values': []},
#              {'id': '065fc368-38bf-4ec6-adc9-dbdf8ad18a69',
#               'metadata': {'Business Summary': 'Standex International '
#                                                'Corporation, together with '
#                                                'subsidiaries, engages in the '
#                                                'manufacture and sale of '
#                                                'various products and services '
#                                                'for commercial and industrial '
#                                                'markets in the United States '
#                                                'and internationally. It '
#                                                'operates through five '
#                                                'segments: Electronics, '
#                                                'Engraving, Scientific, '
#                                                'Engineering Technologies, and '
#                                                'Specialty Solutions. The '
#                                                'Electronics segment offers '
#                                                'reed relays, fluid level, '
#                                                'proximity, motion, flow, HVAC '
#                                                'condensate, and custom '
#                                                'electronics sensors; and '
#                                                'custom wound transformers and '
#                                                'inductors for low and high '
#                                                'frequency, current sense '
#                                                'technology, advanced planar '
#                                                'transformer technology, value '
#                                                'added assembly, and mechanical '
#                                                'packaging applications under '
#                                                'the Standex Electronics, '
#                                                'Renco, and Agile Magnetics. '
#                                                'The Engraving segment provides '
#                                                'mold texturizing, slush '
#                                                'molding tools, roll engraving, '
#                                                'hygiene product tooling, and '
#                                                'low observation vents, as well '
#                                                'as project management and '
#                                                'design services for stealth '
#                                                'aircraft; and process '
#                                                'machinery for various '
#                                                'industries under the Piazza '
#                                                'Rosa, World Client Services, '
#                                                'Tenibac-Graphion, GS '
#                                                'Engineering, and Innovent '
#                                                'brand names. The Scientific '
#                                                'segment offers '
#                                                'temperature-controlled '
#                                                'equipment for the medical, '
#                                                'scientific, pharmaceutical, '
#                                                'biotech, and industrial '
#                                                'markets under the American '
#                                                'BioTech Supply, Lab Research '
#                                                'Products, Corepoint, Cryosafe, '
#                                                'CryoGuard, and Scientific '
#                                                'brands. The Engineering '
#                                                'Technologies segment offers '
#                                                'net and near net formed '
#                                                'single-source customized '
#                                                'solutions that are used in the '
#                                                'manufacture of engineered '
#                                                'components for the aviation, '
#                                                'aerospace, defense, energy, '
#                                                'industrial, medical, marine, '
#                                                'oil and gas, and manned and '
#                                                'unmanned space markets under '
#                                                'the Spincraft brand. The '
#                                                'Specialty Solutions segment '
#                                                'manufactures and sells '
#                                                'refrigerated, heated, and dry '
#                                                'merchandizing display cases; '
#                                                'and single and double acting '
#                                                'telescopic, and piston rod '
#                                                'hydraulic cylinders under the '
#                                                'Federal and Custom Hoist '
#                                                'brands. The company was '
#                                                'founded in 1955 and is '
#                                                'headquartered in Salem, New '
#                                                'Hampshire.',
#                            'City': 'Salem',
#                            'Country': 'United States',
#                            'Industry': 'Specialty Industrial Machinery',
#                            'Name': 'Standex International Corporation',
#                            'Sector': 'Industrials',
#                            'State': 'NH',
#                            'Ticker': 'SXI',
#                            'text': 'Standex International Corporation, '
#                                    'together with subsidiaries, engages in the '
#                                    'manufacture and sale of various products '
#                                    'and services for commercial and industrial '
#                                    'markets in the United States and '
#                                    'internationally. It operates through five '
#                                    'segments: Electronics, Engraving, '
#                                    'Scientific, Engineering Technologies, and '
#                                    'Specialty Solutions. The Electronics '
#                                    'segment offers reed relays, fluid level, '
#                                    'proximity, motion, flow, HVAC condensate, '
#                                    'and custom electronics sensors; and custom '
#                                    'wound transformers and inductors for low '
#                                    'and high frequency, current sense '
#                                    'technology, advanced planar transformer '
#                                    'technology, value added assembly, and '
#                                    'mechanical packaging applications under '
#                                    'the Standex Electronics, Renco, and Agile '
#                                    'Magnetics. The Engraving segment provides '
#                                    'mold texturizing, slush molding tools, '
#                                    'roll engraving, hygiene product tooling, '
#                                    'and low observation vents, as well as '
#                                    'project management and design services for '
#                                    'stealth aircraft; and process machinery '
#                                    'for various industries under the Piazza '
#                                    'Rosa, World Client Services, '
#                                    'Tenibac-Graphion, GS Engineering, and '
#                                    'Innovent brand names. The Scientific '
#                                    'segment offers temperature-controlled '
#                                    'equipment for the medical, scientific, '
#                                    'pharmaceutical, biotech, and industrial '
#                                    'markets under the American BioTech Supply, '
#                                    'Lab Research Products, Corepoint, '
#                                    'Cryosafe, CryoGuard, and Scientific '
#                                    'brands. The Engineering Technologies '
#                                    'segment offers net and near net formed '
#                                    'single-source customized solutions that '
#                                    'are used in the manufacture of engineered '
#                                    'components for the aviation, aerospace, '
#                                    'defense, energy, industrial, medical, '
#                                    'marine, oil and gas, and manned and '
#                                    'unmanned space markets under the Spincraft '
#                                    'brand. The Specialty Solutions segment '
#                                    'manufactures and sells refrigerated, '
#                                    'heated, and dry merchandizing display '
#                                    'cases; and single and double acting '
#                                    'telescopic, and piston rod hydraulic '
#                                    'cylinders under the Federal and Custom '
#                                    'Hoist brands. The company was founded in '
#                                    '1955 and is headquartered in Salem, New '
#                                    'Hampshire.'},
#               'score': 0.509246945,
#               'values': []},
#              {'id': 'f4ef0ea9-9b7d-4548-aeb0-1dddc343c25b',
#               'metadata': {'Business Summary': 'Standex International '
#                                                'Corporation, together with '
#                                                'subsidiaries, engages in the '
#                                                'manufacture and sale of '
#                                                'various products and services '
#                                                'for commercial and industrial '
#                                                'markets in the United States '
#                                                'and internationally. It '
#                                                'operates through five '
#                                                'segments: Electronics, '
#                                                'Engraving, Scientific, '
#                                                'Engineering Technologies, and '
#                                                'Specialty Solutions. The '
#                                                'Electronics segment offers '
#                                                'reed relays, fluid level, '
#                                                'proximity, motion, flow, HVAC '
#                                                'condensate, and custom '
#                                                'electronics sensors; and '
#                                                'custom wound transformers and '
#                                                'inductors for low and high '
#                                                'frequency, current sense '
#                                                'technology, advanced planar '
#                                                'transformer technology, value '
#                                                'added assembly, and mechanical '
#                                                'packaging applications under '
#                                                'the Standex Electronics, '
#                                                'Renco, and Agile Magnetics. '
#                                                'The Engraving segment provides '
#                                                'mold texturizing, slush '
#                                                'molding tools, roll engraving, '
#                                                'hygiene product tooling, and '
#                                                'low observation vents, as well '
#                                                'as project management and '
#                                                'design services for stealth '
#                                                'aircraft; and process '
#                                                'machinery for various '
#                                                'industries under the Piazza '
#                                                'Rosa, World Client Services, '
#                                                'Tenibac-Graphion, GS '
#                                                'Engineering, and Innovent '
#                                                'brand names. The Scientific '
#                                                'segment offers '
#                                                'temperature-controlled '
#                                                'equipment for the medical, '
#                                                'scientific, pharmaceutical, '
#                                                'biotech, and industrial '
#                                                'markets under the American '
#                                                'BioTech Supply, Lab Research '
#                                                'Products, Corepoint, Cryosafe, '
#                                                'CryoGuard, and Scientific '
#                                                'brands. The Engineering '
#                                                'Technologies segment offers '
#                                                'net and near net formed '
#                                                'single-source customized '
#                                                'solutions that are used in the '
#                                                'manufacture of engineered '
#                                                'components for the aviation, '
#                                                'aerospace, defense, energy, '
#                                                'industrial, medical, marine, '
#                                                'oil and gas, and manned and '
#                                                'unmanned space markets under '
#                                                'the Spincraft brand. The '
#                                                'Specialty Solutions segment '
#                                                'manufactures and sells '
#                                                'refrigerated, heated, and dry '
#                                                'merchandizing display cases; '
#                                                'and single and double acting '
#                                                'telescopic, and piston rod '
#                                                'hydraulic cylinders under the '
#                                                'Federal and Custom Hoist '
#                                                'brands. The company was '
#                                                'founded in 1955 and is '
#                                                'headquartered in Salem, New '
#                                                'Hampshire.',
#                            'City': 'Salem',
#                            'Country': 'United States',
#                            'Industry': 'Specialty Industrial Machinery',
#                            'Name': 'Standex International Corporation',
#                            'Sector': 'Industrials',
#                            'State': 'NH',
#                            'Ticker': 'SXI',
#                            'text': 'Standex International Corporation, '
#                                    'together with subsidiaries, engages in the '
#                                    'manufacture and sale of various products '
#                                    'and services for commercial and industrial '
#                                    'markets in the United States and '
#                                    'internationally. It operates through five '
#                                    'segments: Electronics, Engraving, '
#                                    'Scientific, Engineering Technologies, and '
#                                    'Specialty Solutions. The Electronics '
#                                    'segment offers reed relays, fluid level, '
#                                    'proximity, motion, flow, HVAC condensate, '
#                                    'and custom electronics sensors; and custom '
#                                    'wound transformers and inductors for low '
#                                    'and high frequency, current sense '
#                                    'technology, advanced planar transformer '
#                                    'technology, value added assembly, and '
#                                    'mechanical packaging applications under '
#                                    'the Standex Electronics, Renco, and Agile '
#                                    'Magnetics. The Engraving segment provides '
#                                    'mold texturizing, slush molding tools, '
#                                    'roll engraving, hygiene product tooling, '
#                                    'and low observation vents, as well as '
#                                    'project management and design services for '
#                                    'stealth aircraft; and process machinery '
#                                    'for various industries under the Piazza '
#                                    'Rosa, World Client Services, '
#                                    'Tenibac-Graphion, GS Engineering, and '
#                                    'Innovent brand names. The Scientific '
#                                    'segment offers temperature-controlled '
#                                    'equipment for the medical, scientific, '
#                                    'pharmaceutical, biotech, and industrial '
#                                    'markets under the American BioTech Supply, '
#                                    'Lab Research Products, Corepoint, '
#                                    'Cryosafe, CryoGuard, and Scientific '
#                                    'brands. The Engineering Technologies '
#                                    'segment offers net and near net formed '
#                                    'single-source customized solutions that '
#                                    'are used in the manufacture of engineered '
#                                    'components for the aviation, aerospace, '
#                                    'defense, energy, industrial, medical, '
#                                    'marine, oil and gas, and manned and '
#                                    'unmanned space markets under the Spincraft '
#                                    'brand. The Specialty Solutions segment '
#                                    'manufactures and sells refrigerated, '
#                                    'heated, and dry merchandizing display '
#                                    'cases; and single and double acting '
#                                    'telescopic, and piston rod hydraulic '
#                                    'cylinders under the Federal and Custom '
#                                    'Hoist brands. The company was founded in '
#                                    '1955 and is headquartered in Salem, New '
#                                    'Hampshire.'},
#               'score': 0.509246945,
#               'values': []},
#              {'id': '23f3e831-d278-47ed-a5ee-d25891bb11dd',
#               'metadata': {'Business Summary': 'Arrow Electronics, Inc. '
#                                                'provides products, services, '
#                                                'and solutions to industrial '
#                                                'and commercial users of '
#                                                'electronic components and '
#                                                'enterprise computing solutions '
#                                                'in the Americas, Europe, the '
#                                                'Middle East, Africa, and the '
#                                                'Asia Pacific. The company '
#                                                'operates in two segments, '
#                                                'Global Components and Global '
#                                                'Enterprise Computing '
#                                                'Solutions. The Global '
#                                                'Components segment markets and '
#                                                'distributes electronic '
#                                                'components comprising '
#                                                'semiconductor products and '
#                                                'related services; '
#                                                'interconnect, passive, and '
#                                                'electromechanical products, '
#                                                'including capacitors, '
#                                                'resistors, potentiometers, '
#                                                'power supplies, relays, '
#                                                'switches, and connectors; and '
#                                                'computing and memory products, '
#                                                'as well as other products and '
#                                                'services. The Global '
#                                                'Enterprise Computing Solutions '
#                                                'segment offers computing '
#                                                'solutions, such as datacenter, '
#                                                'cloud, security, and analytics '
#                                                'solutions. This segment also '
#                                                'provides access to various '
#                                                'services, including '
#                                                'engineering and integration '
#                                                'support, warehousing and '
#                                                'logistics, marketing '
#                                                'resources, and authorized '
#                                                'hardware and software '
#                                                'training. The company serves '
#                                                'original equipment '
#                                                'manufacturers, value-added '
#                                                'resellers, managed service '
#                                                'providers, contract '
#                                                'manufacturers, and other '
#                                                'commercial customers. Arrow '
#                                                'Electronics, Inc. was founded '
#                                                'in 1935 and is based in '
#                                                'Centennial, Colorado.',
#                            'City': 'Centennial',
#                            'Country': 'United States',
#                            'Industry': 'Electronics & Computer Distribution',
#                            'Name': 'Arrow Electronics, Inc.',
#                            'Sector': 'Technology',
#                            'State': 'CO',
#                            'Ticker': 'ARW',
#                            'text': 'Arrow Electronics, Inc. provides products, '
#                                    'services, and solutions to industrial and '
#                                    'commercial users of electronic components '
#                                    'and enterprise computing solutions in the '
#                                    'Americas, Europe, the Middle East, Africa, '
#                                    'and the Asia Pacific. The company operates '
#                                    'in two segments, Global Components and '
#                                    'Global Enterprise Computing Solutions. The '
#                                    'Global Components segment markets and '
#                                    'distributes electronic components '
#                                    'comprising semiconductor products and '
#                                    'related services; interconnect, passive, '
#                                    'and electromechanical products, including '
#                                    'capacitors, resistors, potentiometers, '
#                                    'power supplies, relays, switches, and '
#                                    'connectors; and computing and memory '
#                                    'products, as well as other products and '
#                                    'services. The Global Enterprise Computing '
#                                    'Solutions segment offers computing '
#                                    'solutions, such as datacenter, cloud, '
#                                    'security, and analytics solutions. This '
#                                    'segment also provides access to various '
#                                    'services, including engineering and '
#                                    'integration support, warehousing and '
#                                    'logistics, marketing resources, and '
#                                    'authorized hardware and software training. '
#                                    'The company serves original equipment '
#                                    'manufacturers, value-added resellers, '
#                                    'managed service providers, contract '
#                                    'manufacturers, and other commercial '
#                                    'customers. Arrow Electronics, Inc. was '
#                                    'founded in 1935 and is based in '
#                                    'Centennial, Colorado.'},
#               'score': 0.504340231,
#               'values': []},
#              {'id': '1eb65003-2d49-477d-ae39-76d42efb2d64',
#               'metadata': {'Business Summary': 'Arrow Electronics, Inc. '
#                                                'provides products, services, '
#                                                'and solutions to industrial '
#                                                'and commercial users of '
#                                                'electronic components and '
#                                                'enterprise computing solutions '
#                                                'in the Americas, Europe, the '
#                                                'Middle East, Africa, and the '
#                                                'Asia Pacific. The company '
#                                                'operates in two segments, '
#                                                'Global Components and Global '
#                                                'Enterprise Computing '
#                                                'Solutions. The Global '
#                                                'Components segment markets and '
#                                                'distributes electronic '
#                                                'components comprising '
#                                                'semiconductor products and '
#                                                'related services; '
#                                                'interconnect, passive, and '
#                                                'electromechanical products, '
#                                                'including capacitors, '
#                                                'resistors, potentiometers, '
#                                                'power supplies, relays, '
#                                                'switches, and connectors; and '
#                                                'computing and memory products, '
#                                                'as well as other products and '
#                                                'services. The Global '
#                                                'Enterprise Computing Solutions '
#                                                'segment offers computing '
#                                                'solutions, such as datacenter, '
#                                                'cloud, security, and analytics '
#                                                'solutions. This segment also '
#                                                'provides access to various '
#                                                'services, including '
#                                                'engineering and integration '
#                                                'support, warehousing and '
#                                                'logistics, marketing '
#                                                'resources, and authorized '
#                                                'hardware and software '
#                                                'training. The company serves '
#                                                'original equipment '
#                                                'manufacturers, value-added '
# ...
#                                                'technical design solutions; '
#                                                'engineering and technical '
#                                                'resources to support product '
#                                                'design, bill of materials '
#                                                'development, and technical '
#                                                'education and training; and '
#                                                'supply chain solutions that '
#                                                'provide support, warehousing, '
#                                                'and logistical services to '
#                                                'original equipment '
#                                                'manufacturers, electronic '
#                                                'manufacturing service '
#                                                'providers, and electronic '
#                                                'component manufacturers. In '
#                                                'addition, this segment '
#                                                'provides embedded solutions, '
#                                                'such as technical design, '
#                                                'integration, and assembly of '
#                                                'embedded products, systems, '
#                                                'and solutions, as well as '
#                                                'embedded display solutions '
#                                                'comprising touch and passive '
#                                                'displays; and develops and '
#                                                'manufactures standard board '
#                                                'and industrial subsystems, and '
#                                                'application-specific devices '
#                                                'that enable it to produce '
#                                                'systems tailored to specific '
#                                                'customer requirements. This '
#                                                'segment serves various '
#                                                'markets, such as automotive, '
#                                                'medical, defense, aerospace, '
#                                                'telecommunications, '
#                                                'industrial, and digital '
#                                                'editing. The Farnell segment '
#                                                'distributes kits, tools, and '
#                                                'electronic and industrial '
#                                                'automation components, as well '
#                                                'as test and measurement '
#                                                'products to engineers and '
#                                                'entrepreneurs. It has '
#                                                'operations in the Americas, '
#                                                'Europe, the Middle East, '
#                                                'Africa, and Asia. Avnet, Inc. '
#                                                'was founded in 1921 and is '
#                                                'headquartered in Phoenix, '
#                                                'Arizona.',
#                            'City': 'Phoenix',
#                            'Country': 'United States',
#                            'Industry': 'Electronics & Computer Distribution',
#                            'Name': 'Avnet, Inc.',
#                            'Sector': 'Technology',
#                            'State': 'AZ',
#                            'Ticker': 'AVT',
#                            'text': 'Avnet, Inc., distributes electronic '
#                                    'component technology. The company operates '
#                                    'through two segments, Electronic '
#                                    'Components and Farnell. The Electronic '
#                                    'Components segment markets, sells, and '
#                                    'distributes semiconductors; interconnect, '
#                                    'passive, and electromechanical components; '
#                                    'and other integrated components from '
#                                    'electronic component manufacturers. It '
#                                    'also offers design chain support that '
#                                    'provides engineers with technical design '
#                                    'solutions; engineering and technical '
#                                    'resources to support product design, bill '
#                                    'of materials development, and technical '
#                                    'education and training; and supply chain '
#                                    'solutions that provide support, '
#                                    'warehousing, and logistical services to '
#                                    'original equipment manufacturers, '
#                                    'electronic manufacturing service '
#                                    'providers, and electronic component '
#                                    'manufacturers. In addition, this segment '
#                                    'provides embedded solutions, such as '
#                                    'technical design, integration, and '
#                                    'assembly of embedded products, systems, '
#                                    'and solutions, as well as embedded display '
#                                    'solutions comprising touch and passive '
#                                    'displays; and develops and manufactures '
#                                    'standard board and industrial subsystems, '
#                                    'and application-specific devices that '
#                                    'enable it to produce systems tailored to '
#                                    'specific customer requirements. This '
#                                    'segment serves various markets, such as '
#                                    'automotive, medical, defense, aerospace, '
#                                    'telecommunications, industrial, and '
#                                    'digital editing. The Farnell segment '
#                                    'distributes kits, tools, and electronic '
#                                    'and industrial automation components, as '
#                                    'well as test and measurement products to '
#                                    'engineers and entrepreneurs. It has '
#                                    'operations in the Americas, Europe, the '
#                                    'Middle East, Africa, and Asia. Avnet, Inc. '
#                                    'was founded in 1921 and is headquartered '
#                                    'in Phoenix, Arizona.'},
#               'score': 0.498096466,
#               'values': []},
#              {'id': '41a67ab5-b81a-49eb-b235-b9319312107d',
#               'metadata': {'Business Summary': 'Avnet, Inc., distributes '
#                                                'electronic component '
#                                                'technology. The company '
#                                                'operates through two segments, '
#                                                'Electronic Components and '
#                                                'Farnell. The Electronic '
#                                                'Components segment markets, '
#                                                'sells, and distributes '
#                                                'semiconductors; interconnect, '
#                                                'passive, and electromechanical '
#                                                'components; and other '
#                                                'integrated components from '
#                                                'electronic component '
#                                                'manufacturers. It also offers '
#                                                'design chain support that '
#                                                'provides engineers with '
#                                                'technical design solutions; '
#                                                'engineering and technical '
#                                                'resources to support product '
#                                                'design, bill of materials '
#                                                'development, and technical '
#                                                'education and training; and '
#                                                'supply chain solutions that '
#                                                'provide support, warehousing, '
#                                                'and logistical services to '
#                                                'original equipment '
#                                                'manufacturers, electronic '
#                                                'manufacturing service '
#                                                'providers, and electronic '
#                                                'component manufacturers. In '
#                                                'addition, this segment '
#                                                'provides embedded solutions, '
#                                                'such as technical design, '
#                                                'integration, and assembly of '
#                                                'embedded products, systems, '
#                                                'and solutions, as well as '
#                                                'embedded display solutions '
#                                                'comprising touch and passive '
#                                                'displays; and develops and '
#                                                'manufactures standard board '
#                                                'and industrial subsystems, and '
#                                                'application-specific devices '
#                                                'that enable it to produce '
#                                                'systems tailored to specific '
#                                                'customer requirements. This '
#                                                'segment serves various '
#                                                'markets, such as automotive, '
#                                                'medical, defense, aerospace, '
#                                                'telecommunications, '
#                                                'industrial, and digital '
#                                                'editing. The Farnell segment '
#                                                'distributes kits, tools, and '
#                                                'electronic and industrial '
#                                                'automation components, as well '
#                                                'as test and measurement '
#                                                'products to engineers and '
#                                                'entrepreneurs. It has '
#                                                'operations in the Americas, '
#                                                'Europe, the Middle East, '
#                                                'Africa, and Asia. Avnet, Inc. '
#                                                'was founded in 1921 and is '
#                                                'headquartered in Phoenix, '
#                                                'Arizona.',
#                            'City': 'Phoenix',
#                            'Country': 'United States',
#                            'Industry': 'Electronics & Computer Distribution',
#                            'Name': 'Avnet, Inc.',
#                            'Sector': 'Technology',
#                            'State': 'AZ',
#                            'Ticker': 'AVT',
#                            'text': 'Avnet, Inc., distributes electronic '
#                                    'component technology. The company operates '
#                                    'through two segments, Electronic '
#                                    'Components and Farnell. The Electronic '
#                                    'Components segment markets, sells, and '
#                                    'distributes semiconductors; interconnect, '
#                                    'passive, and electromechanical components; '
#                                    'and other integrated components from '
#                                    'electronic component manufacturers. It '
#                                    'also offers design chain support that '
#                                    'provides engineers with technical design '
#                                    'solutions; engineering and technical '
#                                    'resources to support product design, bill '
#                                    'of materials development, and technical '
#                                    'education and training; and supply chain '
#                                    'solutions that provide support, '
#                                    'warehousing, and logistical services to '
#                                    'original equipment manufacturers, '
#                                    'electronic manufacturing service '
#                                    'providers, and electronic component '
#                                    'manufacturers. In addition, this segment '
#                                    'provides embedded solutions, such as '
#                                    'technical design, integration, and '
#                                    'assembly of embedded products, systems, '
#                                    'and solutions, as well as embedded display '
#                                    'solutions comprising touch and passive '
#                                    'displays; and develops and manufactures '
#                                    'standard board and industrial subsystems, '
#                                    'and application-specific devices that '
#                                    'enable it to produce systems tailored to '
#                                    'specific customer requirements. This '
#                                    'segment serves various markets, such as '
#                                    'automotive, medical, defense, aerospace, '
#                                    'telecommunications, industrial, and '
#                                    'digital editing. The Farnell segment '
#                                    'distributes kits, tools, and electronic '
#                                    'and industrial automation components, as '
#                                    'well as test and measurement products to '
#                                    'engineers and entrepreneurs. It has '
#                                    'operations in the Americas, Europe, the '
#                                    'Middle East, Africa, and Asia. Avnet, Inc. '
#                                    'was founded in 1921 and is headquartered '
#                                    'in Phoenix, Arizona.'},
#               'score': 0.498096466,
#               'values': []}],
#  'namespace': 'stock-descriptions',
#  'usage': {'read_units': 6}}

# %%
contexts = [item['metadata']['text'] for item in top_matches['matches']]

# %%
augmented_query = "<CONTEXT>\n" + "\n\n-------\n\n".join(contexts[ : 10]) + "\n-------\n</CONTEXT>\n\n\n\nMY QUESTION:\n" + query

# %%
print(augmented_query)
# Out:
# <CONTEXT>
# Kimball Electronics, Inc. engages in the provision of electronics manufacturing, engineering, and supply chain support services to customers in the automotive, medical, and industrial end markets. The Company also offers contract manufacturing services, including engineering and supply chain support for the production of electronic assemblies and other products, including non-electronic components, medical devices, medical disposables, and precision molded plastics, as well as automation, test, and inspection equipment primarily used in automotive, medical, and industrial applications. In addition, it is also involved in the production and testing of printed circuit board assemblies, as well as clean room assembly, cold chain, and product sterilization management activities. Further, the company offers design services and support, supply chain services and support, rapid prototyping and new product introduction support, product design and process validation and qualification, industrialization and automation of manufacturing processes, reliability testing, aftermarket services, drug delivery devices and solutions with and without electronics, and product life cycle management services, as well as and assembly of medical, automotive, and industrial products. It operates in the United States, China, Mexico, Poland, Romania, Thailand, India, Japan, Vietnam, and internationally. Kimball Electronics, Inc. was founded in 1961 and is headquartered in Jasper, Indiana.
#
# -------
#
# Standex International Corporation, together with subsidiaries, engages in the manufacture and sale of various products and services for commercial and industrial markets in the United States and internationally. It operates through five segments: Electronics, Engraving, Scientific, Engineering Technologies, and Specialty Solutions. The Electronics segment offers reed relays, fluid level, proximity, motion, flow, HVAC condensate, and custom electronics sensors; and custom wound transformers and inductors for low and high frequency, current sense technology, advanced planar transformer technology, value added assembly, and mechanical packaging applications under the Standex Electronics, Renco, and Agile Magnetics. The Engraving segment provides mold texturizing, slush molding tools, roll engraving, hygiene product tooling, and low observation vents, as well as project management and design services for stealth aircraft; and process machinery for various industries under the Piazza Rosa, World Client Services, Tenibac-Graphion, GS Engineering, and Innovent brand names. The Scientific segment offers temperature-controlled equipment for the medical, scientific, pharmaceutical, biotech, and industrial markets under the American BioTech Supply, Lab Research Products, Corepoint, Cryosafe, CryoGuard, and Scientific brands. The Engineering Technologies segment offers net and near net formed single-source customized solutions that are used in the manufacture of engineered components for the aviation, aerospace, defense, energy, industrial, medical, marine, oil and gas, and manned and unmanned space markets under the Spincraft brand. The Specialty Solutions segment manufactures and sells refrigerated, heated, and dry merchandizing display cases; and single and double acting telescopic, and piston rod hydraulic cylinders under the Federal and Custom Hoist brands. The company was founded in 1955 and is headquartered in Salem, New Hampshire.
#
# -------
#
# Standex International Corporation, together with subsidiaries, engages in the manufacture and sale of various products and services for commercial and industrial markets in the United States and internationally. It operates through five segments: Electronics, Engraving, Scientific, Engineering Technologies, and Specialty Solutions. The Electronics segment offers reed relays, fluid level, proximity, motion, flow, HVAC condensate, and custom electronics sensors; and custom wound transformers and inductors for low and high frequency, current sense technology, advanced planar transformer technology, value added assembly, and mechanical packaging applications under the Standex Electronics, Renco, and Agile Magnetics. The Engraving segment provides mold texturizing, slush molding tools, roll engraving, hygiene product tooling, and low observation vents, as well as project management and design services for stealth aircraft; and process machinery for various industries under the Piazza Rosa, World Client Services, Tenibac-Graphion, GS Engineering, and Innovent brand names. The Scientific segment offers temperature-controlled equipment for the medical, scientific, pharmaceutical, biotech, and industrial markets under the American BioTech Supply, Lab Research Products, Corepoint, Cryosafe, CryoGuard, and Scientific brands. The Engineering Technologies segment offers net and near net formed single-source customized solutions that are used in the manufacture of engineered components for the aviation, aerospace, defense, energy, industrial, medical, marine, oil and gas, and manned and unmanned space markets under the Spincraft brand. The Specialty Solutions segment manufactures and sells refrigerated, heated, and dry merchandizing display cases; and single and double acting telescopic, and piston rod hydraulic cylinders under the Federal and Custom Hoist brands. The company was founded in 1955 and is headquartered in Salem, New Hampshire.
#
# -------
#
# Standex International Corporation, together with subsidiaries, engages in the manufacture and sale of various products and services for commercial and industrial markets in the United States and internationally. It operates through five segments: Electronics, Engraving, Scientific, Engineering Technologies, and Specialty Solutions. The Electronics segment offers reed relays, fluid level, proximity, motion, flow, HVAC condensate, and custom electronics sensors; and custom wound transformers and inductors for low and high frequency, current sense technology, advanced planar transformer technology, value added assembly, and mechanical packaging applications under the Standex Electronics, Renco, and Agile Magnetics. The Engraving segment provides mold texturizing, slush molding tools, roll engraving, hygiene product tooling, and low observation vents, as well as project management and design services for stealth aircraft; and process machinery for various industries under the Piazza Rosa, World Client Services, Tenibac-Graphion, GS Engineering, and Innovent brand names. The Scientific segment offers temperature-controlled equipment for the medical, scientific, pharmaceutical, biotech, and industrial markets under the American BioTech Supply, Lab Research Products, Corepoint, Cryosafe, CryoGuard, and Scientific brands. The Engineering Technologies segment offers net and near net formed single-source customized solutions that are used in the manufacture of engineered components for the aviation, aerospace, defense, energy, industrial, medical, marine, oil and gas, and manned and unmanned space markets under the Spincraft brand. The Specialty Solutions segment manufactures and sells refrigerated, heated, and dry merchandizing display cases; and single and double acting telescopic, and piston rod hydraulic cylinders under the Federal and Custom Hoist brands. The company was founded in 1955 and is headquartered in Salem, New Hampshire.
#
# -------
#
# Arrow Electronics, Inc. provides products, services, and solutions to industrial and commercial users of electronic components and enterprise computing solutions in the Americas, Europe, the Middle East, Africa, and the Asia Pacific. The company operates in two segments, Global Components and Global Enterprise Computing Solutions. The Global Components segment markets and distributes electronic components comprising semiconductor products and related services; interconnect, passive, and electromechanical products, including capacitors, resistors, potentiometers, power supplies, relays, switches, and connectors; and computing and memory products, as well as other products and services. The Global Enterprise Computing Solutions segment offers computing solutions, such as datacenter, cloud, security, and analytics solutions. This segment also provides access to various services, including engineering and integration support, warehousing and logistics, marketing resources, and authorized hardware and software training. The company serves original equipment manufacturers, value-added resellers, managed service providers, contract manufacturers, and other commercial customers. Arrow Electronics, Inc. was founded in 1935 and is based in Centennial, Colorado.
#
# -------
#
# Arrow Electronics, Inc. provides products, services, and solutions to industrial and commercial users of electronic components and enterprise computing solutions in the Americas, Europe, the Middle East, Africa, and the Asia Pacific. The company operates in two segments, Global Components and Global Enterprise Computing Solutions. The Global Components segment markets and distributes electronic components comprising semiconductor products and related services; interconnect, passive, and electromechanical products, including capacitors, resistors, potentiometers, power supplies, relays, switches, and connectors; and computing and memory products, as well as other products and services. The Global Enterprise Computing Solutions segment offers computing solutions, such as datacenter, cloud, security, and analytics solutions. This segment also provides access to various services, including engineering and integration support, warehousing and logistics, marketing resources, and authorized hardware and software training. The company serves original equipment manufacturers, value-added resellers, managed service providers, contract manufacturers, and other commercial customers. Arrow Electronics, Inc. was founded in 1935 and is based in Centennial, Colorado.
#
# -------
#
# Arrow Electronics, Inc. provides products, services, and solutions to industrial and commercial users of electronic components and enterprise computing solutions in the Americas, Europe, the Middle East, Africa, and the Asia Pacific. The company operates in two segments, Global Components and Global Enterprise Computing Solutions. The Global Components segment markets and distributes electronic components comprising semiconductor products and related services; interconnect, passive, and electromechanical products, including capacitors, resistors, potentiometers, power supplies, relays, switches, and connectors; and computing and memory products, as well as other products and services. The Global Enterprise Computing Solutions segment offers computing solutions, such as datacenter, cloud, security, and analytics solutions. This segment also provides access to various services, including engineering and integration support, warehousing and logistics, marketing resources, and authorized hardware and software training. The company serves original equipment manufacturers, value-added resellers, managed service providers, contract manufacturers, and other commercial customers. Arrow Electronics, Inc. was founded in 1935 and is based in Centennial, Colorado.
#
# -------
#
# Arrow Electronics, Inc. provides products, services, and solutions to industrial and commercial users of electronic components and enterprise computing solutions in the Americas, Europe, the Middle East, Africa, and the Asia Pacific. The company operates in two segments, Global Components and Global Enterprise Computing Solutions. The Global Components segment markets and distributes electronic components comprising semiconductor products and related services; interconnect, passive, and electromechanical products, including capacitors, resistors, potentiometers, power supplies, relays, switches, and connectors; and computing and memory products, as well as other products and services. The Global Enterprise Computing Solutions segment offers computing solutions, such as datacenter, cloud, security, and analytics solutions. This segment also provides access to various services, including engineering and integration support, warehousing and logistics, marketing resources, and authorized hardware and software training. The company serves original equipment manufacturers, value-added resellers, managed service providers, contract manufacturers, and other commercial customers. Arrow Electronics, Inc. was founded in 1935 and is based in Centennial, Colorado.
#
# -------
#
# Avnet, Inc., distributes electronic component technology. The company operates through two segments, Electronic Components and Farnell. The Electronic Components segment markets, sells, and distributes semiconductors; interconnect, passive, and electromechanical components; and other integrated components from electronic component manufacturers. It also offers design chain support that provides engineers with technical design solutions; engineering and technical resources to support product design, bill of materials development, and technical education and training; and supply chain solutions that provide support, warehousing, and logistical services to original equipment manufacturers, electronic manufacturing service providers, and electronic component manufacturers. In addition, this segment provides embedded solutions, such as technical design, integration, and assembly of embedded products, systems, and solutions, as well as embedded display solutions comprising touch and passive displays; and develops and manufactures standard board and industrial subsystems, and application-specific devices that enable it to produce systems tailored to specific customer requirements. This segment serves various markets, such as automotive, medical, defense, aerospace, telecommunications, industrial, and digital editing. The Farnell segment distributes kits, tools, and electronic and industrial automation components, as well as test and measurement products to engineers and entrepreneurs. It has operations in the Americas, Europe, the Middle East, Africa, and Asia. Avnet, Inc. was founded in 1921 and is headquartered in Phoenix, Arizona.
#
# -------
#
# Avnet, Inc., distributes electronic component technology. The company operates through two segments, Electronic Components and Farnell. The Electronic Components segment markets, sells, and distributes semiconductors; interconnect, passive, and electromechanical components; and other integrated components from electronic component manufacturers. It also offers design chain support that provides engineers with technical design solutions; engineering and technical resources to support product design, bill of materials development, and technical education and training; and supply chain solutions that provide support, warehousing, and logistical services to original equipment manufacturers, electronic manufacturing service providers, and electronic component manufacturers. In addition, this segment provides embedded solutions, such as technical design, integration, and assembly of embedded products, systems, and solutions, as well as embedded display solutions comprising touch and passive displays; and develops and manufactures standard board and industrial subsystems, and application-specific devices that enable it to produce systems tailored to specific customer requirements. This segment serves various markets, such as automotive, medical, defense, aerospace, telecommunications, industrial, and digital editing. The Farnell segment distributes kits, tools, and electronic and industrial automation components, as well as test and measurement products to engineers and entrepreneurs. It has operations in the Americas, Europe, the Middle East, Africa, and Asia. Avnet, Inc. was founded in 1921 and is headquartered in Phoenix, Arizona.
# -------
# </CONTEXT>
#
#
#
# MY QUESTION:
# What are some companies that manufacture consumer hardware?

# %%
! pip install groq --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.8/108.8 kB 2.6 MB/s eta 0:00:00

# %%
from groq import Groq
client = Groq(
  api_key=userdata.get("GROQ_API_KEY")
)

# %%
system_prompt = f"""You are an expert at providing answers about stocks. Please answer my question provided.
"""

llm_response = client.chat.completions.create(
    model="llama-3.1-70b-versatile",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": augmented_query}
    ]
)

response = llm_response.choices[0].message.content

# %%
print(response)
# Out:
# Based on the provided context, the following companies can be considered as involved in manufacturing and supplying components for consumer hardware:
#
# 1. Standex International Corporation (through its Electronics segment) - Manufactures custom electronics sensors, custom wound transformers and inductors, and provides engineering and integration support for various industrial and commercial markets.
# 2. Arrow Electronics, Inc. (through its Global Components segment) - Distributes electronic components, including interconnect, passive, and electromechanical products, and computing and memory products, to original equipment manufacturers and other commercial customers.
# 3. Avnet, Inc. (through its Electronic Components segment) - Distributes semiconductors, interconnect, passive, and electromechanical components, and provides design chain support, engineering resources, and supply chain solutions to original equipment manufacturers, electronic manufacturing service providers, and electronic component manufacturers.
#
# However, the company that stands out from the provided context as manufacturing and supplying consumer hardware directly to the consumer is not explicitly mentioned. Standex, Arrow, and Avnet are more focused on supplying components and solutions to the original equipment manufacturers and other industrial/commercial customers.
#
# The context also does not explicitly mention companies that manufacture consumer hardware. However, based on industry research, companies such as HP, Dell, Apple, and Lenovo are well-known manufacturers of consumer hardware such as desktops, laptops, mobile devices, and tablets.
#
# Kimball Electronics, Inc. does not seem to be directly involved in manufacturing consumer hardware. The context describes them as providing contract manufacturing services for customers in the automotive, medical, and industrial end markets.
